# %% [markdown]
# <a href="https://colab.research.google.com/github/jasmin-lilly/jasmin-lilly/blob/main/N_Gram_Analysis_in_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
import nltk
from nltk import ngrams
from collections import Counter
import re

# %%
def clean_text(text):
  cleaned_text = re.sub(r'[^a-zA-Z0-9\s]0',' ',text).lower()
  return cleaned_text

# %%
def ngram_analysis(text,n):
  cleaned_text = clean_text(text)
  words = cleaned_text.split()
  ngrams_list = list(ngrams(words,n))
  ngrams_count = Counter(ngrams_list)
  return ngrams_count

# %%
if __name__ == "__main__":
  text = input("Enter the text")
  n=1
  result=ngram_analysis(text,n)
  print(f"{n}-Gram Analysis:")
  for ngram, count in result.items():
    print(f"{ngram}:{count} times")
# Out:
# Enter the textnavya is a good girl, 2)swathi  is a naugty girl 3)sree is nice girl 4)gowri is innocent girl 5) ritha is nice girl 6) vidya is good girl 4)uma is anice gir
# 1-Gram Analysis:
# ('navya',):1 times
# ('is',):7 times
# ('a',):2 times
# ('good',):2 times
# ('girl,',):1 times
# ('2)swathi',):1 times
# ('naugty',):1 times
# ('girl',):5 times
# ('3)sree',):1 times
# ('nice',):2 times
# ('4)gowri',):1 times
# ('innocent',):1 times
# ('5)',):1 times
# ('ritha',):1 times
# ('6)',):1 times
# ('vidya',):1 times
# ('4)uma',):1 times
# ('anice',):1 times
# ('gir',):1 times

# %%
from IPython import get_ipython
from IPython.display import display
# %%
# !pip install nltk==3.8.1
import nltk
from nltk import ngrams
from collections import Counter
import re
import pandas as pd
# %%
def clean_text(text):
  cleaned_text = re.sub(r'[^a-zA-Z0-9\s]0',' ',text).lower()
  return cleaned_text
# %%
def ngram_analysis(text,n):
  cleaned_text = clean_text(text)
  words = cleaned_text.split()
  ngrams_list = list(ngrams(words,n))
  ngrams_count = Counter(ngrams_list)
  return ngrams_count
# %%
if __name__ == "__main__":
  text = input("Enter the text: ")

  # Perform n-gram analysis for 1, 2, 3, and 4 grams
  results = []
  for n in range(1, 5):
    result = ngram_analysis(text, n)
    results.append(result)

  # Create a list to store data for the table
  table_data = []
  for n, result in enumerate(results):
    for ngram, count in result.items():
      table_data.append([n + 1, ' '.join(ngram), count])  # Join ngram tuple to string

  # Create a Pandas DataFrame for the table
  df = pd.DataFrame(table_data, columns=['N-gram', 'Phrase', 'Frequency'])

  # Display the table
  display(df)
# Out:
# ...
# Enter the text: navya is a good girl, 2)swathi  is a naugty girl 3)sree is nice girl 4)gowri is innocent girl 5) ritha is nice girl 6) vidya is good girl 4)uma is anice gir
#      N-gram               Phrase  Frequency
# 0         1                navya          1
# 1         1                   is          7
# 2         1                    a          2
# 3         1                 good          2
# 4         1                girl,          1
# ..      ...                  ...        ...
# 100       4   vidya is good girl          1
# 101       4   is good girl 4)uma          1
# 102       4   good girl 4)uma is          1
# 103       4  girl 4)uma is anice          1
# 104       4   4)uma is anice gir          1
#
# [105 rows x 3 columns]
